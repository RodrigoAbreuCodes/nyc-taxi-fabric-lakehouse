# %%
# %sql
CREATE VOLUME IF NOT EXISTS nyc_taxi.silver.dim_taxi_zone_raw;

# %%
zones = spark.read.option("header", True).csv("/Volumes/nyc_taxi/silver/dim_taxi_zone_raw/taxi_zone_lookup.csv")

(zones.write.format("delta").mode("overwrite")
    .saveAsTable("nyc_taxi.silver.dim_taxi_zone_raw"))

display(zones)

# %%
# %sql
SHOW TABLES IN nyc_taxi.silver;

# %%
# %sql
SELECT * FROM nyc_taxi.silver.dim_taxi_zone_raw LIMIT 5;
